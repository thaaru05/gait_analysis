# %%
pip install pandas numpy matplotlib seaborn scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Step 1: Importing the CSV File

import pandas as pd

# Load the CSV file into a DataFrame
file_path = 'LX_1.csv'
df = pd.read_csv(file_path)
print(df.head())
# Out:
#    Time (s)  Gyroscope X (deg/s)  Gyroscope Y (deg/s)  Gyroscope Z (deg/s)  \
# 0  0.000000            -0.033461            -0.315105            -0.123777
# 1  0.007603            -0.095607            -0.492139            -0.001204
# 2  0.015205            -0.157655            -0.373523             0.059977
# 3  0.022808            -0.157682            -0.195803             0.059901
# 4  0.032944             0.215757            -0.077330            -0.062784
#
#    Accelerometer X (g)  Accelerometer Y (g)  Accelerometer Z (g)  \
# 0            -0.134688            -0.727212             0.689148
# 1            -0.132208            -0.729116             0.690540
# 2            -0.131288            -0.725257             0.693052
# 3            -0.134655            -0.729594             0.686188
# 4            -0.137066            -0.731591             0.687110
#
#    Magnetometer X (uT)  Magnetometer Y (uT)  Magnetometer Z (uT)  \
# ...

# %%
#Step 2: Data Summary and Preprocessing
# Display basic information about the dataset
print(df.info())

# Check for missing values
print(df.isnull().sum())

# Handle missing values if any (example: fill with mean)
df.fillna(df.mean(), inplace=True)

# Display basic statistics
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4056 entries, 0 to 4055
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Time (s)             4056 non-null   float64
#  1   Gyroscope X (deg/s)  4056 non-null   float64
#  2   Gyroscope Y (deg/s)  4056 non-null   float64
#  3   Gyroscope Z (deg/s)  4056 non-null   float64
#  4   Accelerometer X (g)  4056 non-null   float64
#  5   Accelerometer Y (g)  4056 non-null   float64
#  6   Accelerometer Z (g)  4056 non-null   float64
#  7   Magnetometer X (uT)  4056 non-null   float64
#  8   Magnetometer Y (uT)  4056 non-null   float64
#  9   Magnetometer Z (uT)  4056 non-null   float64
#  10  Barometer (hPa)      4056 non-null   float64
# dtypes: float64(11)
# memory usage: 348.7 KB
# None
# Time (s)               0
# Gyroscope X (deg/s)    0
# Gyroscope Y (deg/s)    0
# Gyroscope Z (deg/s)    0
# Accelerometer X (g)    0
# ...

# %%
#Step 3: Data Analysis
import numpy as np
from scipy import stats

# Median
median = df.median()
print("Median:\n", median)

# Mode
mode = df.mode().iloc[0]
print("Mode:\n", mode)

# Range
range_ = df.max() - df.min()
print("Range:\n", range_)

# Interquartile Range (IQR)
IQR = df.quantile(0.75) - df.quantile(0.25)
print("Interquartile Range (IQR):\n", IQR)

# Skewness
skewness = df.skew()
print("Skewness:\n", skewness)

# Kurtosis
kurtosis = df.kurtosis()
print("Kurtosis:\n", kurtosis)

# Percentiles
percentiles = df.quantile([0.25, 0.5, 0.75])
print("Percentiles:\n", percentiles)

# Quartiles
quartiles = df.quantile([0.25, 0.5, 0.75])
print("Quartiles:\n", quartiles)

# Standard Deviation (SD)
std_dev = df.std()
print("Standard Deviation (SD):\n", std_dev)

# Variance
variance = df.var()
print("Variance:\n", variance)
# Out:
# Median:
#  Time (s)                15.839707
# Gyroscope X (deg/s)     -3.720580
# Gyroscope Y (deg/s)      0.570753
# Gyroscope Z (deg/s)     -1.079523
# Accelerometer X (g)     -0.100245
# Accelerometer Y (g)     -0.740034
# Accelerometer Z (g)      0.686970
# Magnetometer X (uT)      3.056921
# Magnetometer Y (uT)     33.398890
# Magnetometer Z (uT)    -18.993255
# Barometer (hPa)        992.154800
# dtype: float64
# Mode:
#  Time (s)                 0.000000
# Gyroscope X (deg/s)     -4.778595
# Gyroscope Y (deg/s)     -1.499839
# Gyroscope Z (deg/s)      3.148520
# Accelerometer X (g)     -0.129784
# Accelerometer Y (g)     -1.473152
# Accelerometer Z (g)      0.679157
# Magnetometer X (uT)     11.148030
# Magnetometer Y (uT)     33.239520
# Magnetometer Z (uT)     -2.959000
# Barometer (hPa)        992.136000
# Name: 0, dtype: float64
# Range:
#  Time (s)                 31.694545
# Gyroscope X (deg/s)    1162.447600
# Gyroscope Y (deg/s)     854.917500
# ...

# %%
#Step 4: Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram
df.hist(figsize=(10, 10))
plt.show()

# Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.show()

# Pairplot
sns.pairplot(df)
plt.show()

# Heatmap for correlation
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
pip install fpdf
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40713 sha256=6cd1295c6da8464e17ccfdeda0433bf8d41bd5d8bb86234e11a6cd5285081718
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\6e\62\11\dc73d78e40a218ad52e7451f30166e94491be013a7850b5d75
# Successfully built fpdf
# ...

# %%
from fpdf import FPDF

class PDF(FPDF):
    def header(self):
        self.set_font('Arial', 'B', 12)
        self.cell(0, 10, 'Data Analysis Report', 0, 1, 'C')

    def chapter_title(self, title):
        self.set_font('Arial', 'B', 12)
        self.cell(0, 10, title, 0, 1, 'L')
        self.ln(10)

    def chapter_body(self, body):
        self.set_font('Arial', '', 12)
        self.multi_cell(0, 10, body)
        self.ln()

pdf = PDF()
pdf.add_page()

# Add data summary
pdf.chapter_title('Data Summary')
pdf.chapter_body(df.describe().to_string())

# Add data analysis results
pdf.chapter_title('Data Analysis')
pdf.chapter_body(f"Median:\n{median.to_string()}")
pdf.chapter_body(f"Mode:\n{mode.to_string()}")
pdf.chapter_body(f"Range:\n{range_.to_string()}")
pdf.chapter_body(f"IQR:\n{IQR.to_string()}")
pdf.chapter_body(f"Skewness:\n{skewness.to_string()}")
pdf.chapter_body(f"Kurtosis:\n{kurtosis.to_string()}")
pdf.chapter_body(f"Percentiles:\n{percentiles.to_string()}")
pdf.chapter_body(f"Quartiles:\n{quartiles.to_string()}")
pdf.chapter_body(f"Standard Deviation (SD):\n{std_dev.to_string()}")
pdf.chapter_body(f"Variance:\n{variance.to_string()}")

# Save the PDF
pdf.output('data_analysis_report.pdf')
# Out:
# ''
